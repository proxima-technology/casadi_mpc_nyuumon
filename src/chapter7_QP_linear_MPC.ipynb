# %%
# !pip install casadi
from IPython.display import clear_output
import os

import numpy as np
import casadi
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.animation import FuncAnimation

os.makedirs('images',exist_ok=True)
if os.name == 'nt':
    plt.rcParams['font.family'] = 'MS Gothic'
elif os.name == 'posix':
    # !pip install japanize-matplotlib


clear_output()

# %%
m = 1
k = 1
c = 0.5

nx = 2 #状態変数の次元
nu = 1 #制御変数の次元

# 後退ホライズン等
T = 1
K = 20
dt = T/K

#コスト行列
Q = casadi.diag([1,1])
Q_f = casadi.diag([1,1])
R = casadi.diag([1])

# 制約条件
x_lb = [-np.inf,-np.inf]
x_ub = [np.inf,np.inf]
u_lb = [-10]
u_ub = [10]

total = nx*(K+1) + nu*K

# %%
def make_f():
    states = casadi.SX.sym("states",nx)
    ctrls = casadi.SX.sym("ctrls",nu)

    A = casadi.DM([
        [0,1],
        [-k/m,-c/m]
    ])

    B = casadi.DM([
        [0],
        [1/m]
    ])

    states_dot = A @ states + B @ ctrls

    f = casadi.Function("f",[states,ctrls],[states_dot],['x','u'],['x_dot'])
    return f

def make_RK4():
    states = casadi.SX.sym("states",nx)
    ctrls = casadi.SX.sym("ctrls",nu)

    f = make_f()

    r1 = f(x=states,u=ctrls)["x_dot"]
    r2 = f(x=states+dt*r1/2,u=ctrls)["x_dot"]
    r3 = f(x=states+dt*r2/2,u=ctrls)["x_dot"]
    r4 = f(x=states+dt*r3,u=ctrls)["x_dot"]

    states_next = states + dt*(r1+2*r2+2*r3+r4)/6

    RK4 = casadi.Function("RK4",[states,ctrls],[states_next],["x","u"],["x_next"])
    return RK4

def make_integrator():
    states = casadi.SX.sym("states",nx)
    ctrls = casadi.SX.sym("ctrls",nu)

    f = make_f()
    ode = f(x=states, u=ctrls)["x_dot"]

    dae = {"x":states,"p":ctrls,"ode":ode}

    I = casadi.integrator("I","cvodes",dae,0,dt)
    return I

def compute_stage_cost(x,u):
    cost = (casadi.dot(Q@x,x) + casadi.dot(R@u,u)) / 2
    return cost

def compute_final_cost(x):
    cost = casadi.dot(Q_f@x,x) / 2
    return cost

# %%
def make_qp():
    RK4 = make_RK4()

    U = [casadi.SX.sym(f"u_{i}",nu) for i in range(K)]
    X = [casadi.SX.sym(f"x_{i}",nx) for i in range(K+1)]
    G = []

    J = 0

    for k in range(K):
        J += compute_stage_cost(X[k],U[k]) * dt
        eq = X[k+1] - RK4(x=X[k],u=U[k])["x_next"]
        G.append(eq)
    J += compute_final_cost(X[-1])

    nlp = {"x":casadi.vertcat(*X,*U),"f":J,"g":casadi.vertcat(*G)}
    S = casadi.qpsol("S","osqp",nlp)
    return S

def make_nlp():
    RK4 = make_RK4()

    U = [casadi.SX.sym(f"u_{i}",nu) for i in range(K)]
    X = [casadi.SX.sym(f"x_{i}",nx) for i in range(K+1)]
    G = []

    J = 0

    for k in range(K):
        J += compute_stage_cost(X[k],U[k]) * dt
        eq = X[k+1] - RK4(x=X[k],u=U[k])["x_next"]
        G.append(eq)
    J += compute_final_cost(X[-1])

    nlp = {"x":casadi.vertcat(*X,*U),"f":J,"g":casadi.vertcat(*G)}
    S = casadi.nlpsol("S","ipopt",nlp)
    return S

# %%
def compute_optimal_control(S,x_init,x0):
    x_init = x_init.full().ravel().tolist()
    
    lbx = x_init + x_lb*K + u_lb*K
    ubx = x_init + x_ub*K + u_ub*K
    lbg = [0]*nx*K
    ubg = [0]*nx*K

    res = S(lbx=lbx,ubx=ubx,lbg=lbg,ubg=ubg,x0=x0)
    
    offset = nx*(K+1)
    x0 = res["x"]
    u_opt = x0[offset:offset+nu]
    return u_opt, x0

# %%
S_qp = make_qp()
S_nlp = make_nlp()

# %%
t_span = [0,10]
t_eval = np.arange(*t_span,dt)

x_init = casadi.DM([10,0]) # 初期値
x0 = casadi.DM.zeros(total)

I = make_integrator()

X = [x_init]
U = []
x_current = x_init
for t in t_eval:
    u_opt,x0 = compute_optimal_control(S_qp,x_current,x0)
    x_current = I(x0=x_current,p=u_opt)["xf"]
    X.append(x_current)
    U.append(u_opt)

X.pop()
X = np.array(X).reshape(t_eval.size,nx)
U = np.array(U).reshape(t_eval.size,nu)

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
for k in range(nx):
    plt.plot(t_eval,X[:,k],label=f"x_{k}")
plt.legend()

plt.subplot(1,2,2)
for k in range(nu):
    plt.step(t_eval,U[:,k],linestyle="--",label=f"u_{k}")
plt.legend()

plt.show()

# %%
t_span = [0,10]
t_eval = np.arange(*t_span,dt)

x_init = casadi.DM([10,0]) # 初期値
x0 = casadi.DM.zeros(total)

I = make_integrator()

X = [x_init]
U = []
x_current = x_init
for t in t_eval:
    u_opt,x0 = compute_optimal_control(S_nlp,x_current,x0)
    x_current = I(x0=x_current,p=u_opt)["xf"]
    X.append(x_current)
    U.append(u_opt)

X.pop()
X = np.array(X).reshape(t_eval.size,nx)
U = np.array(U).reshape(t_eval.size,nu)

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
for k in range(nx):
    plt.plot(t_eval,X[:,k],label=f"x_{k}")
plt.legend()

plt.subplot(1,2,2)
for k in range(nu):
    plt.step(t_eval,U[:,k],linestyle="--",label=f"u_{k}")
plt.legend()

plt.show()
# Out:
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.5000000e+00 1.00e+01 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  9.3770880e+01 1.78e-15 7.05e-02  -1.0 1.00e+01    -  8.28e-01 1.00e+00h  1
#    2  8.8718728e+01 1.78e-15 1.06e-02  -1.0 3.29e+00    -  9.43e-01 1.00e+00f  1
#    3  8.8078368e+01 1.78e-15 1.55e-15  -1.7 1.34e+00    -  1.00e+00 1.00e+00f  1
#    4  8.8028295e+01 1.78e-15 1.77e-15  -2.5 6.54e-01    -  1.00e+00 1.00e+00f  1
#    5  8.8026703e+01 1.78e-15 2.22e-15  -3.8 1.83e-01    -  1.00e+00 1.00e+00f  1
#    6  8.8026696e+01 1.78e-15 1.28e-15  -3.8 1.43e-02    -  1.00e+00 1.00e+00f  1
#    7  8.8026696e+01 1.78e-15 1.89e-15  -5.7 9.20e-04    -  1.00e+00 1.00e+00h  1
#    8  8.8026696e+01 1.78e-15 3.05e-15  -8.6 1.08e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:   8.8026695859432181e+01    8.8026695859432181e+01
# Dual infeasibility......:   3.0531133177191805e-15    3.0531133177191805e-15
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5142705037858427e-09    2.5142705037858427e-09
# Overall NLP error.......:   2.5142705037858427e-09    2.5142705037858427e-09
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 8
# Total seconds in IPOPT                               = 0.016
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  17.00us (  1.89us)         9
#        nlp_g  |        0 (       0)  52.00us (  5.78us)         9
#   nlp_grad_f  |        0 (       0)  39.00us (  3.55us)        11
#   nlp_hess_l  |        0 (       0)  13.00us (  1.62us)         8
#    nlp_jac_g  |        0 (       0)  39.00us (  3.90us)        10
#        total  |  16.00ms ( 16.00ms)  16.05ms ( 16.05ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.8025491e+01 3.63e-01 7.70e-10  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  8.5028876e+01 1.78e-15 4.33e-04  -1.0 3.57e-01    -  9.81e-01 1.00e+00f  1
#    2  8.5008229e+01 1.78e-15 1.94e-15  -1.7 3.45e-01    -  1.00e+00 1.00e+00f  1
#    3  8.5007836e+01 1.78e-15 2.11e-15  -3.8 7.38e-02    -  1.00e+00 1.00e+00f  1
#    4  8.5007835e+01 1.78e-15 1.67e-15  -5.7 3.73e-03    -  1.00e+00 1.00e+00f  1
#    5  8.5007835e+01 1.78e-15 1.55e-15  -8.6 1.38e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   8.5007835499038492e+01    8.5007835499038492e+01
# Dual infeasibility......:   1.5543122344752192e-15    1.5543122344752192e-15
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5186490851824067e-09    2.5186490851824067e-09
# Overall NLP error.......:   2.5186490851824067e-09    2.5186490851824067e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.007
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  26.00us (  1.73us)        15
#        nlp_g  |        0 (       0)  74.00us (  4.93us)        15
#   nlp_grad_f  |        0 (       0)  61.00us (  3.21us)        19
#   nlp_hess_l  |        0 (       0)  17.00us (  1.31us)        13
#    nlp_jac_g  |        0 (       0)  61.00us (  3.59us)        17
#        total  |   7.00ms (  7.00ms)   7.11ms (  7.11ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.5003602e+01 3.35e-01 6.42e-10  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  8.2061183e+01 1.78e-15 3.77e-04  -1.0 3.29e-01    -  9.82e-01 1.00e+00f  1
#    2  8.2042730e+01 1.78e-15 1.55e-15  -1.7 3.17e-01    -  1.00e+00 1.00e+00f  1
#    3  8.2042426e+01 1.78e-15 1.44e-15  -3.8 6.25e-02    -  1.00e+00 1.00e+00f  1
#    4  8.2042426e+01 1.78e-15 1.22e-15  -5.7 2.62e-03    -  1.00e+00 1.00e+00f  1
#    5  8.2042426e+01 1.78e-15 1.61e-15  -8.6 9.61e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   8.2042426194128183e+01    8.2042426194128183e+01
# Dual infeasibility......:   1.6098233857064770e-15    1.6098233857064770e-15
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5125883724440382e-09    2.5125883724440382e-09
# Overall NLP error.......:   2.5125883724440382e-09    2.5125883724440382e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.009
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  38.00us (  1.81us)        21
#        nlp_g  |        0 (       0) 111.00us (  5.29us)        21
#   nlp_grad_f  |        0 (       0)  92.00us (  3.41us)        27
#   nlp_hess_l  |        0 (       0)  26.00us (  1.44us)        18
#    nlp_jac_g  |        0 (       0)  87.00us (  3.62us)        24
#        total  |  10.00ms ( 10.00ms)   9.11ms (  9.11ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.2034530e+01 3.09e-01 5.45e-10  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.9143657e+01 1.78e-15 3.30e-04  -1.0 3.03e-01    -  9.83e-01 1.00e+00f  1
#    2  7.9127157e+01 1.78e-15 1.28e-15  -1.7 2.94e-01    -  1.00e+00 1.00e+00f  1
#    3  7.9126915e+01 1.78e-15 1.33e-15  -3.8 5.39e-02    -  1.00e+00 1.00e+00f  1
#    4  7.9126915e+01 1.78e-15 2.05e-15  -5.7 1.95e-03    -  1.00e+00 1.00e+00f  1
#    5  7.9126915e+01 1.78e-15 1.44e-15  -8.6 7.49e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.9126914812470574e+01    7.9126914812470574e+01
# Dual infeasibility......:   1.4432899320127035e-15    1.4432899320127035e-15
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5102290130804850e-09    2.5102290130804850e-09
# Overall NLP error.......:   2.5102290130804850e-09    2.5102290130804850e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.005
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  45.00us (  1.67us)        27
#        nlp_g  |        0 (       0) 134.00us (  4.96us)        27
#   nlp_grad_f  |        0 (       0) 103.00us (  2.94us)        35
#   nlp_hess_l  |        0 (       0)  31.00us (  1.35us)        23
#    nlp_jac_g  |        0 (       0) 104.00us (  3.35us)        31
#        total  |   5.00ms (  5.00ms)   5.35ms (  5.35ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  7.9114924e+01 2.84e-01 4.72e-10  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.6274205e+01 1.78e-15 2.89e-04  -1.0 2.78e-01    -  9.85e-01 1.00e+00f  1
#    2  7.6259445e+01 1.78e-15 1.67e-15  -1.7 2.74e-01    -  1.00e+00 1.00e+00f  1
#    3  7.6259247e+01 1.78e-15 1.61e-15  -3.8 4.72e-02    -  1.00e+00 1.00e+00f  1
#    4  7.6259247e+01 1.78e-15 1.44e-15  -5.7 1.51e-03    -  1.00e+00 1.00e+00f  1
#    5  7.6259247e+01 1.78e-15 1.24e-15  -8.6 6.21e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.6259247354582143e+01    7.6259247354582143e+01
# Dual infeasibility......:   1.2351231148954867e-15    1.2351231148954867e-15
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5090377473515856e-09    2.5090377473515856e-09
# Overall NLP error.......:   2.5090377473515856e-09    2.5090377473515856e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.006
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  56.00us (  1.70us)        33
#        nlp_g  |        0 (       0) 164.00us (  4.97us)        33
#   nlp_grad_f  |        0 (       0) 124.00us (  2.88us)        43
#   nlp_hess_l  |        0 (       0)  36.00us (  1.29us)        28
#    nlp_jac_g  |        0 (       0) 128.00us (  3.37us)        38
#        total  |   6.00ms (  6.00ms)   6.45ms (  6.45ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  7.6242896e+01 2.61e-01 4.15e-10  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.3451841e+01 1.78e-15 2.54e-04  -1.0 2.55e-01    -  9.86e-01 1.00e+00f  1
#    2  7.3438632e+01 1.78e-15 1.58e-15  -1.7 2.56e-01    -  1.00e+00 1.00e+00f  1
#    3  7.3438468e+01 1.78e-15 1.39e-15  -3.8 4.18e-02    -  1.00e+00 1.00e+00f  1
#    4  7.3438468e+01 1.78e-15 1.50e-15  -5.7 1.21e-03    -  1.00e+00 1.00e+00h  1
#    5  7.3438468e+01 1.78e-15 1.39e-15  -8.6 5.33e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.3438467986483758e+01    7.3438467986483758e+01
# Dual infeasibility......:   1.3877787807814457e-15    1.3877787807814457e-15
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5083281353825249e-09    2.5083281353825249e-09
# Overall NLP error.......:   2.5083281353825249e-09    2.5083281353825249e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.007
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  65.00us (  1.67us)        39
#        nlp_g  |        0 (       0) 189.00us (  4.85us)        39
#   nlp_grad_f  |        0 (       0) 142.00us (  2.78us)        51
#   nlp_hess_l  |        0 (       0)  43.00us (  1.30us)        33
#    nlp_jac_g  |        0 (       0) 151.00us (  3.36us)        45
#        total  |   7.00ms (  7.00ms)   7.30ms (  7.30ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  7.3417630e+01 2.38e-01 3.69e-10  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.0676478e+01 1.78e-15 2.23e-04  -1.0 2.44e-01    -  9.87e-01 1.00e+00f  1
#    2  7.0664654e+01 1.78e-15 1.22e-15  -1.7 2.41e-01    -  1.00e+00 1.00e+00f  1
#    3  7.0664515e+01 1.78e-15 1.61e-15  -3.8 3.74e-02    -  1.00e+00 1.00e+00f  1
#    4  7.0664515e+01 1.78e-15 1.22e-15  -5.7 1.00e-03    -  1.00e+00 1.00e+00h  1
#    5  7.0664515e+01 1.78e-15 1.67e-15  -8.6 4.69e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.0664514570658909e+01    7.0664514570658909e+01
# Dual infeasibility......:   1.6653345369377348e-15    1.6653345369377348e-15
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5078579466076734e-09    2.5078579466076734e-09
# Overall NLP error.......:   2.5078579466076734e-09    2.5078579466076734e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.006
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  76.00us (  1.69us)        45
#        nlp_g  |        0 (       0) 214.00us (  4.76us)        45
#   nlp_grad_f  |        0 (       0) 156.00us (  2.64us)        59
#   nlp_hess_l  |        0 (       0)  48.00us (  1.26us)        38
#    nlp_jac_g  |        0 (       0) 170.00us (  3.27us)        52
#        total  |   6.00ms (  6.00ms)   6.30ms (  6.30ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  7.0639181e+01 2.17e-01 3.31e-10  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.7948757e+01 1.78e-15 1.97e-04  -1.0 2.40e-01    -  9.88e-01 1.00e+00f  1
#    2  6.7938170e+01 1.78e-15 8.88e-16  -1.7 2.27e-01    -  1.00e+00 1.00e+00f  1
#    3  6.7938051e+01 1.78e-15 1.39e-15  -3.8 3.37e-02    -  1.00e+00 1.00e+00f  1
#    4  6.7938051e+01 1.78e-15 1.72e-15  -5.7 8.42e-04    -  1.00e+00 1.00e+00h  1
#    5  6.7938051e+01 1.78e-15 1.67e-15  -8.6 4.18e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.7938050657221780e+01    6.7938050657221780e+01
# Dual infeasibility......:   1.6653345369377348e-15    1.6653345369377348e-15
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5075235607015271e-09    2.5075235607015271e-09
# Overall NLP error.......:   2.5075235607015271e-09    2.5075235607015271e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.007
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  88.00us (  1.73us)        51
#        nlp_g  |        0 (       0) 247.00us (  4.84us)        51
#   nlp_grad_f  |        0 (       0) 175.00us (  2.61us)        67
#   nlp_hess_l  |        0 (       0)  56.00us (  1.30us)        43
#    nlp_jac_g  |        0 (       0) 237.00us (  4.02us)        59
#        total  |   8.00ms (  8.00ms)   7.60ms (  7.60ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.7908303e+01 1.97e-01 2.99e-10  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.5269743e+01 1.78e-15 1.74e-04  -1.0 2.36e-01    -  9.89e-01 1.00e+00f  1
#    2  6.5260261e+01 1.78e-15 1.50e-15  -1.7 2.14e-01    -  1.00e+00 1.00e+00f  1
#    3  6.5260159e+01 1.78e-15 1.11e-15  -3.8 3.06e-02    -  1.00e+00 1.00e+00f  1
#    4  6.5260159e+01 1.78e-15 1.61e-15  -5.7 7.22e-04    -  1.00e+00 1.00e+00h  1
#    5  6.5260159e+01 1.78e-15 1.72e-15  -8.6 3.77e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.5260158507903256e+01    6.5260158507903256e+01
# Dual infeasibility......:   1.7208456881689926e-15    1.7208456881689926e-15
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5072737906098347e-09    2.5072737906098347e-09
# Overall NLP error.......:   2.5072737906098347e-09    2.5072737906098347e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.011
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  99.00us (  1.74us)        57
#        nlp_g  |        0 (       0) 285.00us (  5.00us)        57
#   nlp_grad_f  |        0 (       0) 197.00us (  2.63us)        75
#   nlp_hess_l  |        0 (       0)  66.00us (  1.37us)        48
#    nlp_jac_g  |        0 (       0) 263.00us (  3.98us)        66
#        total  |  11.00ms ( 11.00ms)  11.07ms ( 11.07ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.5226154e+01 1.78e-01 2.71e-10  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.2640891e+01 1.78e-15 1.53e-04  -1.0 2.32e-01    -  9.89e-01 1.00e+00f  1
#    2  6.2632401e+01 1.78e-15 1.61e-15  -1.7 2.02e-01    -  1.00e+00 1.00e+00f  1
#    3  6.2632311e+01 1.78e-15 1.33e-15  -3.8 2.79e-02    -  1.00e+00 1.00e+00f  1
#    4  6.2632311e+01 1.78e-15 1.44e-15  -5.7 6.27e-04    -  1.00e+00 1.00e+00h  1
#    5  6.2632311e+01 1.78e-15 1.33e-15  -8.6 3.43e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.2632310675206170e+01    6.2632310675206170e+01
# Dual infeasibility......:   1.3322676295501878e-15    1.3322676295501878e-15
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5070804505296803e-09    2.5070804505296803e-09
# Overall NLP error.......:   2.5070804505296803e-09    2.5070804505296803e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.007
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 108.00us (  1.71us)        63
#        nlp_g  |   1.00ms ( 15.87us) 314.00us (  4.98us)        63
#   nlp_grad_f  |        0 (       0) 220.00us (  2.65us)        83
#   nlp_hess_l  |        0 (       0)  72.00us (  1.36us)        53
#    nlp_jac_g  |        0 (       0) 290.00us (  3.97us)        73
#        total  |   8.00ms (  8.00ms)   7.83ms (  7.83ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.2594267e+01 1.61e-01 2.47e-10  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.0063910e+01 1.78e-15 1.36e-04  -1.0 2.28e-01    -  9.90e-01 1.00e+00f  1
#    2  6.0056308e+01 1.78e-15 1.33e-15  -1.7 1.91e-01    -  1.00e+00 1.00e+00f  1
#    3  6.0056229e+01 1.78e-15 1.05e-15  -3.8 2.56e-02    -  1.00e+00 1.00e+00f  1
#    4  6.0056229e+01 8.88e-16 1.11e-15  -5.7 5.52e-04    -  1.00e+00 1.00e+00h  1
#    5  6.0056229e+01 1.78e-15 1.11e-15  -8.6 3.13e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.0056229180383028e+01    6.0056229180383028e+01
# Dual infeasibility......:   1.1102230246251565e-15    1.1102230246251565e-15
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5069266839362571e-09    2.5069266839362571e-09
# Overall NLP error.......:   2.5069266839362571e-09    2.5069266839362571e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.008
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 119.00us (  1.72us)        69
#        nlp_g  |   1.00ms ( 14.49us) 348.00us (  5.04us)        69
#   nlp_grad_f  |        0 (       0) 240.00us (  2.64us)        91
#   nlp_hess_l  |        0 (       0)  81.00us (  1.40us)        58
#    nlp_jac_g  |        0 (       0) 314.00us (  3.92us)        80
#        total  |   9.00ms (  9.00ms)   8.64ms (  8.64ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.0014409e+01 1.44e-01 2.26e-10  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.7540633e+01 1.78e-15 1.20e-04  -1.0 2.24e-01    -  9.91e-01 1.00e+00f  1
#    2  5.7533828e+01 1.78e-15 1.28e-15  -1.7 1.81e-01    -  1.00e+00 1.00e+00f  1
#    3  5.7533758e+01 1.78e-15 1.28e-15  -3.8 2.35e-02    -  1.00e+00 1.00e+00f  1
#    4  5.7533758e+01 1.78e-15 1.33e-15  -5.7 4.91e-04    -  1.00e+00 1.00e+00h  1
#    5  5.7533758e+01 1.78e-15 1.67e-15  -8.6 2.88e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.7533757699872552e+01    5.7533757699872552e+01
# Dual infeasibility......:   1.6653345369377348e-15    1.6653345369377348e-15
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5068017513277608e-09    2.5068017513277608e-09
# Overall NLP error.......:   2.5068017513277608e-09    2.5068017513277608e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.007
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 129.00us (  1.72us)        75
#        nlp_g  |   1.00ms ( 13.33us) 379.00us (  5.05us)        75
#   nlp_grad_f  |        0 (       0) 257.00us (  2.60us)        99
#   nlp_hess_l  |        0 (       0)  89.00us (  1.41us)        63
#    nlp_jac_g  |        0 (       0) 335.00us (  3.85us)        87
#        total  |   8.00ms (  8.00ms)   7.63ms (  7.63ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  5.7488458e+01 1.48e-01 2.08e-10  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.5072928e+01 1.78e-15 1.07e-04  -1.0 2.20e-01    -  9.91e-01 1.00e+00f  1
#    2  5.5066838e+01 1.78e-15 1.33e-15  -1.7 1.72e-01    -  1.00e+00 1.00e+00f  1
#    3  5.5066776e+01 1.78e-15 8.88e-16  -3.8 2.17e-02    -  1.00e+00 1.00e+00f  1
#    4  5.5066776e+01 1.78e-15 1.39e-15  -5.7 4.40e-04    -  1.00e+00 1.00e+00h  1
#    5  5.5066776e+01 1.78e-15 1.44e-15  -8.6 2.65e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.5066775732992411e+01    5.5066775732992411e+01
# Dual infeasibility......:   1.4432899320127035e-15    1.4432899320127035e-15
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5066984661406838e-09    2.5066984661406838e-09
# Overall NLP error.......:   2.5066984661406838e-09    2.5066984661406838e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.008
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 143.00us (  1.77us)        81
#        nlp_g  |   1.00ms ( 12.35us) 407.00us (  5.02us)        81
#   nlp_grad_f  |        0 (       0) 275.00us (  2.57us)       107
#   nlp_hess_l  |        0 (       0)  96.00us (  1.41us)        68
#    nlp_jac_g  |        0 (       0) 360.00us (  3.83us)        94
#        total  |   8.00ms (  8.00ms)   8.03ms (  8.03ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  5.5018316e+01 1.53e-01 1.92e-10  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.2662633e+01 1.78e-15 9.45e-05  -1.0 2.15e-01    -  9.92e-01 1.00e+00f  1
#    2  5.2657185e+01 1.78e-15 1.39e-15  -1.7 1.63e-01    -  1.00e+00 1.00e+00f  1
#    3  5.2657129e+01 8.88e-16 1.17e-15  -3.8 2.00e-02    -  1.00e+00 1.00e+00f  1
#    4  5.2657129e+01 1.78e-15 1.50e-15  -5.7 3.98e-04    -  1.00e+00 1.00e+00h  1
#    5  5.2657129e+01 8.88e-16 1.55e-15  -8.6 2.46e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.2657128930747838e+01    5.2657128930747838e+01
# Dual infeasibility......:   1.5543122344752192e-15    1.5543122344752192e-15
# Constraint violation....:   8.8817841970012523e-16    8.8817841970012523e-16
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5066118293431962e-09    2.5066118293431962e-09
# Overall NLP error.......:   2.5066118293431962e-09    2.5066118293431962e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.005
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 151.00us (  1.74us)        87
#        nlp_g  |   1.00ms ( 11.49us) 428.00us (  4.92us)        87
#   nlp_grad_f  |        0 (       0) 290.00us (  2.52us)       115
#   nlp_hess_l  |        0 (       0) 101.00us (  1.38us)        73
#    nlp_jac_g  |        0 (       0) 378.00us (  3.74us)       101
#        total  |   5.00ms (  5.00ms)   5.40ms (  5.40ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  5.2605843e+01 1.58e-01 1.77e-10  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.0311495e+01 1.78e-15 8.39e-05  -1.0 2.11e-01    -  9.92e-01 1.00e+00f  1
#    2  5.0306624e+01 1.78e-15 1.28e-15  -1.7 1.55e-01    -  1.00e+00 1.00e+00f  1
#    3  5.0306573e+01 8.88e-16 9.44e-16  -3.8 1.86e-02    -  1.00e+00 1.00e+00f  1
#    4  5.0306573e+01 1.78e-15 1.50e-15  -5.7 3.61e-04    -  1.00e+00 1.00e+00h  1
#    5  5.0306573e+01 1.78e-15 1.33e-15  -8.6 2.28e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.0306573413255762e+01    5.0306573413255762e+01
# Dual infeasibility......:   1.3322676295501878e-15    1.3322676295501878e-15
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5065382535037205e-09    2.5065382535037205e-09
# Overall NLP error.......:   2.5065382535037205e-09    2.5065382535037205e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.006
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 158.00us (  1.70us)        93
#        nlp_g  |   1.00ms ( 10.75us) 451.00us (  4.85us)        93
#   nlp_grad_f  |        0 (       0) 306.00us (  2.49us)       123
#   nlp_hess_l  |        0 (       0) 104.00us (  1.33us)        78
#    nlp_jac_g  |        0 (       0) 400.00us (  3.70us)       108
#        total  |   7.00ms (  7.00ms)   6.22ms (  6.22ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  5.0252803e+01 1.62e-01 1.64e-10  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  4.8021132e+01 1.78e-15 7.44e-05  -1.0 2.07e-01    -  9.93e-01 1.00e+00f  1
#    2  4.8016778e+01 1.78e-15 1.39e-15  -1.7 1.47e-01    -  1.00e+00 1.00e+00f  1
#    3  4.8016732e+01 8.88e-16 1.72e-15  -3.8 1.72e-02    -  1.00e+00 1.00e+00f  1
#    4  4.8016732e+01 8.88e-16 9.44e-16  -5.7 3.30e-04    -  1.00e+00 1.00e+00h  1
#    5  4.8016732e+01 1.78e-15 1.22e-15  -8.6 2.12e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.8016732385769259e+01    4.8016732385769259e+01
# Dual infeasibility......:   1.2212453270876722e-15    1.2212453270876722e-15
# Constraint violation....:   1.7763568394002505e-15    1.7763568394002505e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5064750976262811e-09    2.5064750976262811e-09
# Overall NLP error.......:   2.5064750976262811e-09    2.5064750976262811e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.007
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 167.00us (  1.69us)        99
#        nlp_g  |   1.00ms ( 10.10us) 475.00us (  4.80us)        99
#   nlp_grad_f  |        0 (       0) 322.00us (  2.46us)       131
#   nlp_hess_l  |        0 (       0) 109.00us (  1.31us)        83
#    nlp_jac_g  |        0 (       0) 423.00us (  3.68us)       115
#        total  |   7.00ms (  7.00ms)   7.15ms (  7.15ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# ...
# Dual infeasibility......:   1.5178830414797062e-18    1.5178830414797062e-18
# Constraint violation....:   1.7347234759768071e-18    1.7347234759768071e-18
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5059039001230363e-09    2.5059039001230363e-09
# Overall NLP error.......:   2.5059039001230363e-09    2.5059039001230363e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.006
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (852.51ns)   1.34ms (  1.15us)      1173
#        nlp_g  |   2.00ms (  1.71us)   4.56ms (  3.89us)      1173
#   nlp_grad_f  |   3.00ms (  1.92us)   2.88ms (  1.84us)      1563
#   nlp_hess_l  |        0 (       0) 841.00us (859.92ns)       978
#    nlp_jac_g  |  10.00ms (  7.31us)   5.77ms (  4.22us)      1368
#        total  |   6.00ms (  6.00ms)   6.13ms (  6.13ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  7.4788296e-05 3.77e-04 1.59e-13  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.9969750e-05 1.73e-18 1.52e-11  -1.0 3.77e-04    -  1.00e+00 1.00e+00h  1
#    2  6.9968688e-05 1.73e-18 1.41e-18  -2.5 8.11e-05    -  1.00e+00 1.00e+00h  1
#    3  6.9968687e-05 1.73e-18 1.19e-18  -3.8 1.57e-06    -  1.00e+00 1.00e+00h  1
#    4  6.9968687e-05 1.73e-18 1.63e-18  -5.7 1.44e-07    -  1.00e+00 1.00e+00h  1
#    5  6.9968687e-05 1.73e-18 9.76e-19  -8.6 1.78e-09    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.9968686943685073e-05    6.9968686943685073e-05
# Dual infeasibility......:   9.7578195523695399e-19    9.7578195523695399e-19
# Constraint violation....:   1.7347234759768071e-18    1.7347234759768071e-18
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5059038885462031e-09    2.5059038885462031e-09
# Overall NLP error.......:   2.5059038885462031e-09    2.5059038885462031e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.006
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (848.18ns)   1.35ms (  1.15us)      1179
#        nlp_g  |   2.00ms (  1.70us)   4.58ms (  3.89us)      1179
#   nlp_grad_f  |   3.00ms (  1.91us)   2.90ms (  1.84us)      1571
#   nlp_hess_l  |        0 (       0) 846.00us (860.63ns)       983
#    nlp_jac_g  |  10.00ms (  7.27us)   5.80ms (  4.22us)      1375
#        total  |   7.00ms (  7.00ms)   6.70ms (  6.70ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.9702592e-05 3.69e-04 1.55e-13  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.5168971e-05 1.73e-18 1.31e-11  -1.0 3.69e-04    -  1.00e+00 1.00e+00h  1
#    2  6.5168029e-05 8.67e-19 1.30e-18  -2.5 7.63e-05    -  1.00e+00 1.00e+00h  1
#    3  6.5168028e-05 1.73e-18 1.08e-18  -3.8 1.54e-06    -  1.00e+00 1.00e+00h  1
#    4  6.5168028e-05 1.73e-18 1.25e-18  -5.7 1.39e-07    -  1.00e+00 1.00e+00h  1
#    5  6.5168028e-05 1.73e-18 1.08e-18  -8.6 1.72e-09    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.5168028104161004e-05    6.5168028104161004e-05
# Dual infeasibility......:   1.0842021724855044e-18    1.0842021724855044e-18
# Constraint violation....:   1.7347234759768071e-18    1.7347234759768071e-18
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5059038772211208e-09    2.5059038772211208e-09
# Overall NLP error.......:   2.5059038772211208e-09    2.5059038772211208e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.007
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (843.88ns)   1.36ms (  1.15us)      1185
#        nlp_g  |   2.00ms (  1.69us)   4.61ms (  3.89us)      1185
#   nlp_grad_f  |   3.00ms (  1.90us)   2.95ms (  1.87us)      1579
#   nlp_hess_l  |        0 (       0) 851.00us (861.34ns)       988
#    nlp_jac_g  |  10.00ms (  7.24us)   5.88ms (  4.25us)      1382
#        total  |   7.00ms (  7.00ms)   7.45ms (  7.45ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.4914554e-05 3.60e-04 1.50e-13  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.0652752e-05 1.73e-18 1.13e-11  -1.0 3.60e-04    -  1.00e+00 1.00e+00h  1
#    2  6.0651915e-05 1.73e-18 1.08e-18  -2.5 7.16e-05    -  1.00e+00 1.00e+00h  1
#    3  6.0651914e-05 1.73e-18 8.13e-19  -3.8 1.50e-06    -  1.00e+00 1.00e+00h  1
#    4  6.0651914e-05 1.73e-18 1.19e-18  -5.7 1.34e-07    -  1.00e+00 1.00e+00h  1
#    5  6.0651914e-05 1.73e-18 9.76e-19  -8.6 1.66e-09    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.0651914313653786e-05    6.0651914313653786e-05
# Dual infeasibility......:   9.7578195523695399e-19    9.7578195523695399e-19
# Constraint violation....:   1.7347234759768071e-18    1.7347234759768071e-18
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5059038661501954e-09    2.5059038661501954e-09
# Overall NLP error.......:   2.5059038661501954e-09    2.5059038661501954e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.005
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (839.63ns)   1.37ms (  1.15us)      1191
#        nlp_g  |   2.00ms (  1.68us)   4.62ms (  3.88us)      1191
#   nlp_grad_f  |   3.00ms (  1.89us)   2.96ms (  1.87us)      1587
#   nlp_hess_l  |        0 (       0) 854.00us (860.02ns)       993
#    nlp_jac_g  |  10.00ms (  7.20us)   5.89ms (  4.24us)      1389
#        total  |   5.00ms (  5.00ms)   5.00ms (  5.00ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.0410769e-05 3.51e-04 1.46e-13  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.6407963e-05 1.73e-18 9.67e-12  -1.0 3.51e-04    -  1.00e+00 1.00e+00h  1
#    2  5.6407216e-05 1.73e-18 1.84e-18  -2.5 6.72e-05    -  1.00e+00 1.00e+00h  1
#    3  5.6407215e-05 1.73e-18 1.08e-18  -3.8 1.47e-06    -  1.00e+00 1.00e+00h  1
#    4  5.6407215e-05 8.67e-19 1.63e-18  -5.7 1.29e-07    -  1.00e+00 1.00e+00h  1
#    5  5.6407215e-05 1.73e-18 1.14e-18  -8.6 1.60e-09    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.6407215420308542e-05    5.6407215420308542e-05
# Dual infeasibility......:   1.1384122811097797e-18    1.1384122811097797e-18
# Constraint violation....:   1.7347234759768071e-18    1.7347234759768071e-18
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5059038553351770e-09    2.5059038553351770e-09
# Overall NLP error.......:   2.5059038553351770e-09    2.5059038553351770e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.007
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (835.42ns)   1.37ms (  1.15us)      1197
#        nlp_g  |   2.00ms (  1.67us)   4.65ms (  3.88us)      1197
#   nlp_grad_f  |   3.00ms (  1.88us)   2.98ms (  1.87us)      1595
#   nlp_hess_l  |        0 (       0) 859.00us (860.72ns)       998
#    nlp_jac_g  |  10.00ms (  7.16us)   5.91ms (  4.23us)      1396
#        total  |   7.00ms (  7.00ms)   7.49ms (  7.49ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      137
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       60
#
# Total number of variables............................:       60
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       20
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       40
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  5.6178081e-05 3.42e-04 1.41e-13  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.2421756e-05 1.73e-18 8.26e-12  -1.0 3.42e-04    -  1.00e+00 1.00e+00h  1
#    2  5.2421088e-05 8.67e-19 1.90e-18  -2.5 6.30e-05    -  1.00e+00 1.00e+00h  1
#    3  5.2421087e-05 1.73e-18 1.19e-18  -3.8 1.44e-06    -  1.00e+00 1.00e+00h  1
#    4  5.2421087e-05 1.73e-18 1.03e-18  -5.7 1.25e-07    -  1.00e+00 1.00e+00h  1
#    5  5.2421087e-05 8.67e-19 4.88e-19  -8.6 1.55e-09    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.2421086709209981e-05    5.2421086709209981e-05
# Dual infeasibility......:   4.8789097761847700e-19    4.8789097761847700e-19
# Constraint violation....:   8.6736173798840355e-19    8.6736173798840355e-19
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5059038447765155e-09    2.5059038447765155e-09
# Overall NLP error.......:   2.5059038447765155e-09    2.5059038447765155e-09
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT                               = 0.005
#
# EXIT: Optimal Solution Found.
#            S  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (831.26ns)   1.38ms (  1.15us)      1203
#        nlp_g  |   2.00ms (  1.66us)   4.67ms (  3.88us)      1203
#   nlp_grad_f  |   3.00ms (  1.87us)   2.99ms (  1.87us)      1603
#   nlp_hess_l  |        0 (       0) 864.00us (861.42ns)      1003
#    nlp_jac_g  |  10.00ms (  7.13us)   5.93ms (  4.23us)      1403
#        total  |   5.00ms (  5.00ms)   5.37ms (  5.37ms)         1
