# %%
# !pip install casadi
from IPython.display import clear_output
import os

import numpy as np
import casadi
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.animation import FuncAnimation

os.makedirs("images",exist_ok=True)
if os.name == "nt":
    plt.rcParams["font.family"] = "MS Gothic"
elif os.name == "posix":
    # !pip install japanize-matplotlib


clear_output()

# %%
a = 0.12
b = 0.12
c = 0.048
d = 0.12
e = 0.12
f = 0.024

# 予測ホライズン等
K = 30

nu = 1 #制御変数の次元
nx = 2 #状態変数の次元
total = nx*(K+1) + nu*K #最適化変数の次元

# コスト関数の重み
Q = casadi.diag([1,1])
Q_f = casadi.diag([1,1])
R = casadi.diag([0.0001])

# 制約条件
x_lb = [0,0]
x_ub = [np.inf,np.inf]
u_lb = [0]
u_ub = [1]

# 目標値
x_ref = casadi.DM([1,1])
u_ref = casadi.DM([0])

# %%
def make_F():
    states = casadi.SX.sym("states",nx)
    ctrls = casadi.SX.sym("ctrls",nu)

    x = states[0]
    y = states[1]
    u = ctrls[0]

    x_next = (1+a)*x -b*x*y - c*x*u
    y_next = (1-d)*y + e*x*y - f*y*u

    states_next = casadi.vertcat(x_next,y_next)

    F = casadi.Function("F",[states,ctrls],[states_next],["x","u"],["x_next"])
    return F

# %%
t_span = [0,100]
t_eval = np.arange(*t_span)

x_init = casadi.DM([0.5,0.7]) # 初期値

F = make_F()

X = [x_init]
x_current = x_init
for t in t_eval:
    x_current = F(x=x_current,u=0)["x_next"]
    X.append(x_current)

X.pop()
X = np.array(X).reshape(t_eval.size,nx)

plt.figure(figsize=(12,4))

plt.subplot(1,1,1)
for k in range(nx):
    plt.plot(t_eval,X[:,k],label=f"x_{k}")
plt.legend()

# plt.savefig("images/chap4_mpc_no_control.png")
plt.show()

# %%
def compute_stage_cost(x,u):
    x_diff = x - x_ref
    u_diff = u - u_ref
    cost = (casadi.dot(Q@x_diff,x_diff) + casadi.dot(R@u_diff,u_diff)) / 2
    return cost

def compute_terminal_cost(x):
    x_diff = x - x_ref
    cost = casadi.dot(Q_f@x_diff,x_diff) / 2
    return cost

# %%
def make_nlp():
    F = make_F()

    U = [casadi.SX.sym(f"u_{i}",nu) for i in range(K)]
    X = [casadi.SX.sym(f"x_{i}",nx) for i in range(K+1)]
    G = []

    J = 0

    for k in range(K):
        J += compute_stage_cost(X[k],U[k])
        eq = X[k+1] - F(x=X[k],u=U[k])["x_next"]
        G.append(eq)
    J += compute_terminal_cost(X[-1])

    option = {"print_time":False,
              "discrete": [False]*nx*(K+1) + [True]*nu*K,
              "bonmin":{
                "print_level":0, "sb":"yes",
                "nlp_log_at_root":0, "nlp_log_level":0,
                "lp_log_level":0, "milp_log_level":0,
                "bb_log_level":0, "fp_log_level":0,
                "oa_log_level":0}
             }
    nlp = {"x":casadi.vertcat(*X,*U),"f":J,"g":casadi.vertcat(*G)}
    S = casadi.nlpsol("S","bonmin",nlp,option)
    return S

# %%
def compute_optimal_control(S,x_init,x0):
    x_init = x_init.full().ravel().tolist()
    
    lbx = x_init + x_lb*K + u_lb*K
    ubx = x_init + x_ub*K + u_ub*K
    lbg = [0]*nx*K
    ubg = [0]*nx*K

    res = S(lbx=lbx,ubx=ubx,lbg=lbg,ubg=ubg,x0=x0)
    
    offset = nx*(K+1)
    x0 = res["x"]
    u_opt = x0[offset:offset+nu]
    return u_opt, x0

# %%
S = make_nlp()

# %%
t_span = [0,100]
t_eval = np.arange(*t_span,1)

x_init = casadi.DM([0.5,0.7]) # 初期値
x0 = casadi.DM.zeros(total)

F = make_F()

X = [x_init]
U = []
x_current = x_init
for t in t_eval:
    u_opt,x0 = compute_optimal_control(S,x_current,x0)
    x_current = F(x=x_current,u=u_opt)["x_next"]
    X.append(x_current)
    U.append(u_opt)
# Out:
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.9257149       16 0.090606
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.9267339        4 0.023806
# NLP0014I             2         OPT 5.9267338        2 0.006027
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.9267338        0 0.003007
# NLP0014I             2         OPT 5.9267339        4 0.010372
# NLP0014I             3         OPT 5.9296203        5 0.019495
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.9244366       10 0.026257
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.9244366        0 0.001708
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.9244366        0 0.001546
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.9016707        8 0.018253
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.9036281        5 0.004469
# NLP0014I             2         OPT 5.9036282        3 0.0026
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.9036282        0 0.000634
# NLP0014I             2         OPT 5.9055732        5 0.006368
# NLP0014I             3         OPT 5.9036281        5 0.006723
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.83679        5 0.00502
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.83679        0 0.000653
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.83679        0 0.000619
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.7485771       12 0.00672
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.7486164        4 0.000586
# NLP0014I             2         OPT 5.7486165        2 0.001502
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.7486165        0 0.00048
# NLP0014I             2         OPT 5.7640707        5 0.003478
# NLP0014I             3         OPT 5.7486164        4 0.002249
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.6317594       10 0.006079
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.6329944        4 0.002711
# NLP0014I             2         OPT 5.6329943        2 0.001413
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.6329943        0 0.000308
# NLP0014I             2         OPT 5.6329944        4 0.002736
# NLP0014I             3         OPT 5.6432133        5 0.002968
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.4885106       12 0.006506
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.4885106        0 0.000585
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.4885106        0 0.000524
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.3343164       11 0.005903
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.3343164        0 0.000569
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.3343164        0 0.000506
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.1737946       12 0.006306
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.174011        4 0.002696
# NLP0014I             2         OPT 5.174011        2 0.00136
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.174011        0 0.000454
# NLP0014I             2         OPT 5.1976564       11 0.005916
# NLP0014I             3         OPT 5.174011        4 0.002438
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.0085709       11 0.005992
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.0109032        5 0.003089
# NLP0014I             2         OPT 5.0109032        2 0.001392
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 5.0109032        0 0.000443
# NLP0014I             2         OPT 5.0271088       12 0.006272
# NLP0014I             3         OPT 5.0109032        5 0.002874
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.8428911       13 0.006719
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.8478418        5 0.003166
# NLP0014I             2         OPT 4.8478417        2 0.00136
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.8478417        0 0.000435
# NLP0014I             2         OPT 4.8584515       13 0.006816
# NLP0014I             3         OPT 4.8478418        5 0.002954
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.6797381       15 0.007707
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.6797409        5 0.00338
# NLP0014I             2         OPT 4.6799805        5 0.003077
# NLP0014I             3         OPT 4.6880888        8 0.004577
# NLP0014I             4         OPT 4.68837        5 0.003031
# NLP0014I             5         OPT 4.68837        3 0.001792
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.68837        0 0.000485
# NLP0014I             2         OPT 4.6799805        6 0.003739
# NLP0014I             3         OPT 4.6799931        9 0.004867
# NLP0014I             4         OPT 4.6927994       13 0.0066
# NLP0014I             5         OPT 4.6869707        8 0.004612
# NLP0014I             6         OPT 4.6813595        8 0.004508
# NLP0014I             7         OPT 4.6797409        5 0.003043
# NLP0014I             8         OPT 4.6869707        8 0.0044
# NLP0014I             9         OPT 4.7230793       10 0.005267
# NLP0014I            10         OPT 4.6870489        8 0.004407
# NLP0014I            11         OPT 4.6870489        8 0.004396
# NLP0014I            12         OPT 4.6870652        6 0.003383
# NLP0014I             2         OPT 4.6870652        0 0.00078
# NLP0014I            13         OPT 4.68837        5 0.00303
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.5187402       13 0.006894
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.5187402        5 0.003183
# NLP0014I             2         OPT 4.5188918        8 0.004464
# NLP0014I             3         OPT 4.5189143        6 0.00344
# NLP0014I             4         OPT 4.5192118        5 0.002982
# NLP0014I             5         OPT 4.5286506        9 0.004885
# NLP0014I             6         OPT 4.5296962        5 0.002914
# NLP0014I             7         OPT 4.5296962        3 0.001782
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.5296962        0 0.000463
# NLP0014I             2         OPT 4.5294961       14 0.007623
# NLP0014I             3         OPT 4.5282078       12 0.006226
# NLP0014I             4         OPT 4.5188855        8 0.004499
# NLP0014I             5         OPT 4.5189931        8 0.004369
# NLP0014I             6         OPT 4.5188851        7 0.004007
# NLP0014I             7         OPT 4.5190086        8 0.004445
# NLP0014I             8         OPT 4.5194836        9 0.004896
# NLP0014I             9         OPT 4.5188904       12 0.006369
# NLP0014I            10         OPT 4.521994       10 0.005436
# NLP0014I            11         OPT 4.5187402        5 0.003066
# NLP0014I            12         OPT 4.5282078       12 0.006119
# NLP0014I            13         OPT 4.5592438       10 0.005373
# NLP0014I            14         OPT 4.5289137        9 0.004726
# NLP0014I            15         OPT 4.5289137        9 0.004739
# NLP0014I            16         OPT 4.5294961       14 0.007118
# NLP0014I            17         OPT 4.5298429       12 0.006122
# NLP0014I            18         OPT 4.5654229       10 0.005198
# NLP0014I            19         OPT 4.5291306        9 0.004776
# NLP0014I            20         OPT 4.5290991        8 0.00436
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            21         OPT 4.5296962        7 0.003929
# NLP0014I            22         OPT 4.5296157        5 0.003015
# NLP0014I            23         OPT 4.5300493        6 0.003361
# NLP0014I            24         OPT 4.5318627        5 0.00294
# NLP0014I            25         OPT 4.5291306        9 0.004838
# NLP0014I            26         OPT 4.5340131        7 0.003881
# NLP0014I            27         OPT 4.5291445        6 0.003408
# NLP0014I             2         OPT 4.5291445        0 0.000724
# NLP0014I            28         OPT 4.5319439        5 0.002993
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.3584714       15 0.007861
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.3584714        5 0.003409
# NLP0014I             2         OPT 4.3585998        7 0.004083
# NLP0014I             3         OPT 4.3587517        8 0.004188
# NLP0014I             4         OPT 4.3587791        6 0.003507
# NLP0014I             5         OPT 4.3596524       11 0.004844
# NLP0014I             6         OPT 4.3598037        5 0.003041
# NLP0014I             7         OPT 4.3598037        5 0.002956
# NLP0014I             8         OPT 4.3703532       11 0.005617
# NLP0014I             9         OPT 4.3726096        5 0.002893
# NLP0014I            10         OPT 4.3726096        3 0.001818
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.3726096        0 0.000465
# NLP0014I             2         OPT 4.3671443       11 0.006138
# NLP0014I             3         OPT 4.3700083       13 0.006578
# NLP0014I             4         OPT 4.3587533        8 0.004404
# NLP0014I             5         OPT 4.3587371        9 0.00481
# NLP0014I             6         OPT 4.3586051        8 0.004488
# NLP0014I             7         OPT 4.3587217       12 0.006249
# NLP0014I             8         OPT 4.358606        7 0.003886
# NLP0014I             9         OPT 4.3587405       11 0.005999
# NLP0014I            10         OPT 4.3585998        7 0.004004
# NLP0014I            11         OPT 4.3587638        8 0.004532
# NLP0014I            12         OPT 4.3605372        9 0.004942
# NLP0014I            13         OPT 4.3584714        5 0.003004
# NLP0014I            14         OPT 4.3671443       11 0.005679
# NLP0014I            15         OPT 4.3672236       11 0.005764
# NLP0014I            16         OPT 4.4069344       13 0.006658
# NLP0014I            17         OPT 4.3672236       11 0.005806
# NLP0014I            18         OPT 4.3700083       13 0.006621
# NLP0014I            19         OPT 4.3964586       11 0.005823
# NLP0014I            20         OPT 4.3719814        9 0.004762
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            21         OPT 4.3719814        9 0.004709
# NLP0014I            22         OPT 4.3673161       12 0.006231
# NLP0014I            23         OPT 4.3681702        9 0.004788
# NLP0014I            24         OPT 4.367393       12 0.006229
# NLP0014I            25         OPT 4.367706       13 0.00685
# NLP0014I            26         OPT 4.3676342       10 0.005324
# NLP0014I            27         OPT 4.3676864       13 0.006811
# NLP0014I            28         OPT 4.3679359       11 0.005708
# NLP0014I            29         OPT 4.3720042        7 0.003814
# NLP0014I            30         OPT 4.3680373        8 0.00423
# NLP0014I            31         OPT 4.3681724        7 0.003988
# NLP0014I            32         OPT 4.3680373        8 0.004241
# NLP0014I             2         OPT 4.3680373        0 0.000721
# NLP0014I            33         OPT 4.3676927        9 0.004865
# NLP0014I            34         OPT 4.370171       10 0.005331
# NLP0014I            35         OPT 4.3677012        6 0.003439
# NLP0014I             3         OPT 4.3677012        0 0.000745
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.1968344       14 0.007294
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.1968748        7 0.00491
# NLP0014I             2         OPT 4.1969331        7 0.00403
# NLP0014I             3         OPT 4.1971392       11 0.005912
# NLP0014I             4         OPT 4.1971393        6 0.003539
# NLP0014I             5         OPT 4.1971393        5 0.003085
# NLP0014I             6         OPT 4.1972538        6 0.003572
# NLP0014I             7         OPT 4.2050532       11 0.005779
# NLP0014I             8         OPT 4.2050589       10 0.005311
# NLP0014I             9         OPT 4.2051986        9 0.004776
# NLP0014I            10         OPT 4.2052039        5 0.002843
# NLP0014I            11         OPT 4.2052039        3 0.001775
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.2052039        0 0.000478
# NLP0014I             2         OPT 4.1969519        7 0.004852
# NLP0014I             3         OPT 4.1970887        9 0.004896
# NLP0014I             4         OPT 4.196949        7 0.003934
# NLP0014I             5         OPT 4.1971149        9 0.004952
# NLP0014I             6         OPT 4.2036774       13 0.006635
# NLP0014I             7         OPT 4.2101459       14 0.007087
# NLP0014I             8         OPT 4.1969498        7 0.003985
# NLP0014I             9         OPT 4.1971348        9 0.004909
# NLP0014I            10         OPT 4.1969331        9 0.004894
# NLP0014I            11         OPT 4.1970991        9 0.001545
# NLP0014I            12         OPT 4.1969438        6 0.003555
# NLP0014I            13         OPT 4.1971578        8 0.004426
# NLP0014I            14         OPT 4.1980462        9 0.004834
# NLP0014I            15         OPT 4.1968748        7 0.003984
# NLP0014I            16         OPT 4.2036774       13 0.00654
# NLP0014I            17         OPT 4.2036775        8 0.00436
# NLP0014I            18         OPT 4.2468574       14 0.007106
# NLP0014I            19         OPT 4.2036775        8 0.002628
# NLP0014I            20         OPT 4.2072598       11 0.004708
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            21         OPT 4.2036775        7 0.003828
# NLP0014I            22         OPT 4.2036775        7 0.00379
# NLP0014I            23         OPT 4.2039052        9 0.004376
# NLP0014I            24         OPT 4.2043066       11 0.005666
# NLP0014I            25         OPT 4.2039769       10 0.005207
# NLP0014I            26         OPT 4.2043086       11 0.005702
# NLP0014I            27         OPT 4.2042017        9 0.004739
# NLP0014I            28         OPT 4.2042926       12 0.006135
# NLP0014I            29         OPT 4.2043635       11 0.005479
# NLP0014I            30         OPT 4.2134988        9 0.00475
# NLP0014I            31         OPT 4.2043635       10 0.005049
# NLP0014I            32         OPT 4.2043635       10 0.005112
# NLP0014I             2         OPT 4.2043635        1 0.00177
# NLP0014I            33         OPT 4.2046905        8 0.004423
# NLP0014I            34         OPT 4.2043701        9 0.00486
# NLP0014I            35         OPT 4.2073571       10 0.005039
# NLP0014I            36         OPT 4.2043668       11 0.005813
# NLP0014I            37         OPT 4.2047436       12 0.006564
# NLP0014I            38         OPT 4.2043857        9 0.00476
# NLP0014I            39         OPT 4.2053553       14 0.006893
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.0309299       13 0.006802
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.0363136        8 0.004757
# NLP0014I             2         OPT 4.0363725        7 0.00397
# NLP0014I             3         OPT 4.0364368        7 0.003873
# NLP0014I             4         OPT 4.0365047        7 0.00392
# NLP0014I             5         OPT 4.0367579        7 0.003907
# NLP0014I             6         OPT 4.0368398        6 0.00342
# NLP0014I             7         OPT 4.0368398        6 0.003364
# NLP0014I             8         OPT 4.0374385        9 0.004715
# NLP0014I             9         OPT 4.0374392        9 0.00476
# NLP0014I            10         OPT 4.0374734        7 0.003806
# NLP0014I            11         OPT 4.0375757        5 0.002922
# NLP0014I            12         OPT 4.0375757        3 0.001817
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 4.0375757        0 0.000457
# NLP0014I             2         OPT 4.0310332        7 0.004603
# NLP0014I             3         OPT 4.0311908       10 0.00539
# NLP0014I             4         OPT 4.0310228        8 0.004369
# NLP0014I             5         OPT 4.031187       10 0.005319
# NLP0014I             6         OPT 4.0310287        7 0.003911
# NLP0014I             7         OPT 4.0312202       11 0.005797
# NLP0014I             8         OPT 4.0310272        7 0.003862
# NLP0014I             9         OPT 4.0312441       10 0.005351
# NLP0014I            10         OPT 4.0310271        7 0.003888
# NLP0014I            11         OPT 4.0312645       11 0.005814
# NLP0014I            12         OPT 4.0310216        6 0.00345
# NLP0014I            13         OPT 4.0312869       10 0.005332
# NLP0014I            14         OPT 4.0316166       10 0.005304
# NLP0014I            15         OPT 4.0310951       12 0.006214
# NLP0014I            16         OPT 4.0363136        8 0.004307
# NLP0014I            17         OPT 4.0457728       13 0.006606
# NLP0014I            18         OPT 4.0363136        8 0.004269
# NLP0014I            19         OPT 4.0366088       12 0.006029
# NLP0014I            20         OPT 4.0392998        9 0.00472
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            21         OPT 4.0367619       11 0.005617
# NLP0014I            22         OPT 4.0367619       11 0.005505
# NLP0014I            23         OPT 4.0367619       12 0.006063
# NLP0014I            24         OPT 4.0823302       13 0.006587
# NLP0014I            25         OPT 4.0367619       12 0.006021
# NLP0014I            26         OPT 4.0367234        9 0.004817
# NLP0014I            27         OPT 4.0367775        9 0.004822
# NLP0014I            28         OPT 4.037181        9 0.004863
# NLP0014I            29         OPT 4.0369472        9 0.004769
# NLP0014I            30         OPT 4.0371876        9 0.004822
# NLP0014I            31         OPT 4.0373089        9 0.004736
# NLP0014I            32         OPT 4.037193        9 0.004713
# NLP0014I            33         OPT 4.0372422       11 0.005839
# NLP0014I            34         OPT 4.0380376        9 0.004783
# NLP0014I            35         OPT 4.037288        9 0.004582
# NLP0014I            36         OPT 4.03926        6 0.003297
# NLP0014I            37         OPT 4.037288        5 0.002828
# NLP0014I            38         OPT 4.0483084        5 0.002948
# NLP0014I            39         OPT 4.037288        5 0.002884
# NLP0014I             2         OPT 4.037288        0 0.00079
# NLP0014I            40         OPT 4.0368276       12 0.006322
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            41         OPT 4.0446815       10 0.00527
# NLP0014I            42         OPT 4.0368276       10 0.005301
# NLP0014I            43         OPT 4.0368276       10 0.00527
# NLP0014I            44         OPT 4.0371818       13 0.006482
# NLP0014I            45         OPT 4.0369064        8 0.004274
# NLP0014I            46         OPT 4.0374734       10 0.00526
# NLP0014I            47         OPT 4.0369064        6 0.003372
# NLP0014I            48         OPT 4.0410637       12 0.006084
# NLP0014I            49         OPT 4.0371404        8 0.004285
# NLP0014I            50         OPT 4.0372044        9 0.004667
# NLP0014I            51         OPT 4.0381293        8 0.00407
# NLP0014I            52         OPT 4.038788        7 0.003714
# NLP0014I            53         OPT 4.0372304        9 0.004801
# NLP0014I            54         OPT 4.0380871       11 0.005656
# NLP0014I            55         OPT 4.0372514        9 0.004788
# NLP0014I            56         OPT 4.0385874       10 0.005307
# NLP0014I            57         OPT 4.0372803        9 0.004812
# NLP0014I            58         OPT 4.0388542       14 0.007015
# NLP0014I            59         OPT 4.0372608       13 0.006448
# NLP0014I            60         OPT 4.0379917       12 0.00597
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            61         OPT 4.0374514        9 0.004676
# NLP0014I            62         OPT 4.0387154       11 0.005574
# NLP0014I            63         OPT 4.0372306       10 0.005214
# NLP0014I            64         OPT 4.038311        8 0.004151
# NLP0014I            65         OPT 4.0372531       10 0.005341
# NLP0014I            66         OPT 4.0389049        8 0.004283
# NLP0014I            67         OPT 4.0375508        6 0.003271
# NLP0014I            68         OPT 4.039685       12 0.005937
# NLP0014I            69         OPT 4.0372526        7 0.003685
# NLP0014I            70         OPT 4.0426721       11 0.005061
# NLP0014I            71         OPT 4.0373306        5 0.003016
# NLP0014I            72         OPT 4.0393718        5 0.002907
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 3.8570988       14 0.007657
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 3.8613817        8 0.004513
# NLP0014I             2         OPT 3.8614327        9 0.004868
# NLP0014I             3         OPT 3.8614888        7 0.003868
# NLP0014I             4         OPT 3.8615484        7 0.003911
# NLP0014I             5         OPT 3.8616137        8 0.004485
# NLP0014I             6         OPT 3.8618425        7 0.003875
# NLP0014I             7         OPT 3.8621276        8 0.004231
# NLP0014I             8         OPT 3.8622555        6 0.003372
# NLP0014I             9         OPT 3.8647073        5 0.002805
# NLP0014I            10         OPT 3.8647073        2 0.001362
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 3.8647073        0 0.000447
# NLP0014I             2         OPT 3.8574932       10 0.005905
# NLP0014I             3         OPT 3.8573483       12 0.006501
# NLP0014I             4         OPT 3.8571907        7 0.004078
# NLP0014I             5         OPT 3.8573462       10 0.006707
# NLP0014I             6         OPT 3.8571907        7 0.004006
# NLP0014I             7         OPT 3.857365       12 0.006453
# NLP0014I             8         OPT 3.8571856        7 0.003894
# NLP0014I             9         OPT 3.8573964       12 0.006515
# NLP0014I            10         OPT 3.8571823        7 0.004035
# NLP0014I            11         OPT 3.8574242       11 0.005911
# NLP0014I            12         OPT 3.8571803        7 0.004077
# NLP0014I            13         OPT 3.8574493       10 0.005516
# NLP0014I            14         OPT 3.8571797        6 0.00358
# NLP0014I            15         OPT 3.8574714       10 0.005544
# NLP0014I            16         OPT 3.8571746        6 0.003588
# NLP0014I            17         OPT 3.8574904       10 0.005506
# NLP0014I            18         OPT 3.8613817        8 0.00205
# NLP0014I            19         OPT 3.8731753       13 0.006676
# NLP0014I            20         OPT 3.8613817        8 0.004395
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            21         OPT 3.8617186       13 0.005559
# NLP0014I            22         OPT 3.8638781        8 0.004458
# NLP0014I            23         OPT 3.8620972       15 0.007587
# NLP0014I            24         OPT 3.8616369        8 0.004464
# NLP0014I            25         OPT 3.8616845        8 0.004371
# NLP0014I            26         OPT 3.8621193        9 0.004838
# NLP0014I            27         OPT 3.8618339        8 0.004375
# NLP0014I            28         OPT 3.8621394        9 0.004933
# NLP0014I            29         OPT 3.8621519        8 0.00438
# NLP0014I            30         OPT 3.86213        9 0.004856
# NLP0014I            31         OPT 3.8621757        9 0.004796
# NLP0014I            32         OPT 3.8633413        9 0.004839
# NLP0014I            33         OPT 3.8621779        8 0.004292
# NLP0014I            34         OPT 3.8644725        7 0.003799
# NLP0014I            35         OPT 3.8626859        8 0.004181
# NLP0014I            36         OPT 3.8626063        6 0.00349
# NLP0014I            37         OPT 3.8635789        5 0.002807
# NLP0014I             2         OPT 3.8635789        0 0.00074
# NLP0014I            38         OPT 3.8620972       15 0.007551
# NLP0014I            39         OPT 3.8689174        8 0.004399
# NLP0014I            40         OPT 3.8621084       14 0.006954
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            41         OPT 3.8621084       14 0.007062
# NLP0014I            42         OPT 3.8638781        8 0.004501
# NLP0014I            43         OPT 3.8621752       12 0.006086
# NLP0014I            44         OPT 3.8625052       14 0.007251
# NLP0014I            45         OPT 3.8624179        8 0.004414
# NLP0014I            46         OPT 3.8631566       15 0.007773
# NLP0014I            47         OPT 3.8631581       14 0.007294
# NLP0014I            48         OPT 3.9099363       14 0.007198
# NLP0014I            49         OPT 3.8631581       14 0.007172
# NLP0014I            50         OPT 3.8627417        8 0.004323
# NLP0014I            51         OPT 3.8647532       15 0.007529
# NLP0014I            52         OPT 3.8628973        9 0.00484
# NLP0014I            53         OPT 3.8670476       11 0.00567
# NLP0014I            54         OPT 3.8629521       10 0.005207
# NLP0014I            55         OPT 3.8633682        8 0.004371
# NLP0014I            56         OPT 3.8632121        8 0.004206
# NLP0014I            57         OPT 3.8633758        8 0.00426
# NLP0014I            58         OPT 3.8632121        5 0.003075
# NLP0014I             3         OPT 3.8632121        0 0.000776
# NLP0014I            59         OPT 3.8621566       10 0.005391
# NLP0014I            60         OPT 3.8631278       11 0.005759
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            61         OPT 3.8622295       10 0.005254
# NLP0014I            62         OPT 3.8631786       10 0.00533
# NLP0014I            63         OPT 3.8622303       10 0.005403
# NLP0014I            64         OPT 3.8639634       17 0.008372
# NLP0014I            65         OPT 3.8623978       11 0.005805
# NLP0014I            66         OPT 3.8631093       11 0.005791
# NLP0014I            67         OPT 3.8623978        7 0.003802
# NLP0014I            68         OPT 3.8640424        6 0.003404
# NLP0014I            69         OPT 3.8658873        5 0.002871
# NLP0014I            70         OPT 3.8628182        6 0.003344
# NLP0014I            71         OPT 3.8628193        6 0.003276
# NLP0014I             4         OPT 3.8628193        0 0.00072
# NLP0014I            72         OPT 3.862165       10 0.005345
# NLP0014I            73         OPT 3.8633979        9 0.004777
# NLP0014I            74         OPT 3.8622347       10 0.005308
# NLP0014I            75         OPT 3.8632081       10 0.005522
# NLP0014I            76         OPT 3.8622354       10 0.005374
# NLP0014I            77         OPT 3.8642787       15 0.007647
# NLP0014I            78         OPT 3.8629934        6 0.003314
# NLP0014I            79         OPT 3.8638313       13 0.00652
# NLP0014I            80         OPT 3.8622806       11 0.005844
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            81         OPT 3.8627284        9 0.004807
# NLP0014I            82         OPT 3.8623661       11 0.00562
# NLP0014I            83         OPT 3.8632578        9 0.004841
# NLP0014I            84         OPT 3.8623663        9 0.004792
# NLP0014I            85         OPT 3.8666012       15 0.007402
# NLP0014I            86         OPT 3.8623759        6 0.003483
# NLP0014I             5         OPT 3.8623759        0 0.00076
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 3.6708046       14 0.007566
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 3.6708046        5 0.003435
# NLP0014I             2         OPT 3.6742639        7 0.003944
# NLP0014I             3         OPT 3.6743073        7 0.003971
# NLP0014I             4         OPT 3.6743555        7 0.003903
# NLP0014I             5         OPT 3.6744074        7 0.003812
# NLP0014I             6         OPT 3.6744662        7 0.003923
# NLP0014I             7         OPT 3.6745964        9 0.005049
# NLP0014I             8         OPT 3.6747244        7 0.003841
# NLP0014I             9         OPT 3.6751353        9 0.004801
# NLP0014I            10         OPT 3.6751833        6 0.003389
# NLP0014I            11         OPT 3.6755174        5 0.002926
# NLP0014I            12         OPT 3.6755174        2 0.001372
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 3.6755174        0 0.000465
# NLP0014I             2         OPT 3.6708971        8 0.004821
# NLP0014I             3         OPT 3.6710419       12 0.006407
# NLP0014I             4         OPT 3.6710273        9 0.004994
# NLP0014I             5         OPT 3.671085       13 0.006822
# NLP0014I             6         OPT 3.6708874        7 0.003998
# NLP0014I             7         OPT 3.6710755       13 0.00698
# NLP0014I             8         OPT 3.6708822        7 0.003966
# NLP0014I             9         OPT 3.6711095       11 0.005946
# NLP0014I            10         OPT 3.6708777        7 0.003952
# NLP0014I            11         OPT 3.6711434       10 0.005435
# NLP0014I            12         OPT 3.6708744        7 0.003967
# NLP0014I            13         OPT 3.671175       10 0.005471
# NLP0014I            14         OPT 3.6708722        7 0.003898
# NLP0014I            15         OPT 3.6712027        9 0.004999
# NLP0014I            16         OPT 3.6708713        7 0.004031
# NLP0014I            17         OPT 3.671227        9 0.004922
# NLP0014I            18         OPT 3.6708668        6 0.003558
# NLP0014I            19         OPT 3.6712341        9 0.004986
# NLP0014I            20         OPT 3.6742639       10 0.005278
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            21         OPT 3.6878651       13 0.006627
# NLP0014I            22         OPT 3.6730675       10 0.005328
# NLP0014I            23         OPT 3.6708046        5 0.003033
# NLP0014I            24         OPT 3.6742639       10 0.005283
# NLP0014I            25         OPT 3.6742639        7 0.003793
# NLP0014I            26         OPT 3.6763638        9 0.004784
# NLP0014I            27         OPT 3.6744148        7 0.00387
# NLP0014I            28         OPT 3.6751841       16 0.007981
# NLP0014I            29         OPT 3.6811361        8 0.00427
# NLP0014I            30         OPT 3.6753249       13 0.006539
# NLP0014I            31         OPT 3.6753249       13 0.006703
# NLP0014I            32         OPT 3.6744594        7 0.003902
# NLP0014I            33         OPT 3.6749631        9 0.004885
# NLP0014I            34         OPT 3.674585        8 0.004376
# NLP0014I            35         OPT 3.6749255        8 0.004395
# NLP0014I            36         OPT 3.6748595        8 0.004447
# NLP0014I            37         OPT 3.6749428        9 0.004961
# NLP0014I            38         OPT 3.6753558        9 0.00494
# NLP0014I            39         OPT 3.675039        9 0.005092
# NLP0014I            40         OPT 3.675039        7 0.003888
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            41         OPT 3.6774187        9 0.004842
# NLP0014I            42         OPT 3.6751082        7 0.003863
# NLP0014I            43         OPT 3.6762118        8 0.004433
# NLP0014I            44         OPT 3.6755174        9 0.00462
# NLP0014I            45         OPT 3.6754793        7 0.003751
# NLP0014I            46         OPT 3.676039        5 0.002881
# NLP0014I            47         OPT 3.6802334       12 0.005548
# NLP0014I            48         OPT 3.6749498        8 0.004202
# NLP0014I            49         OPT 3.6760569        9 0.004878
# NLP0014I            50         OPT 3.6751045        9 0.004843
# NLP0014I            51         OPT 3.6757301       11 0.005715
# NLP0014I            52         OPT 3.6751591        9 0.002497
# NLP0014I            53         OPT 3.6756702       15 0.005696
# NLP0014I            54         OPT 3.6753499        7 0.003767
# NLP0014I            55         OPT 3.6764642       12 0.005973
# NLP0014I            56         OPT 3.6756987        9 0.004692
# NLP0014I            57         OPT 3.6767331        7 0.003817
# NLP0014I            58         OPT 3.674966       10 0.005282
# NLP0014I            59         OPT 3.6763829        9 0.004897
# NLP0014I            60         OPT 3.6751223       11 0.005717
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            61         OPT 3.6757553       11 0.005736
# NLP0014I            62         OPT 3.675318        8 0.004381
# NLP0014I            63         OPT 3.678036       14 0.006891
# NLP0014I            64         OPT 3.6753885        6 0.00337
# NLP0014I            65         OPT 3.6780973       13 0.00658
# NLP0014I            66         OPT 3.6763686        5 0.002982
# NLP0014I            67         OPT 3.6788226       12 0.006141
# NLP0014I            68         OPT 3.6749751        9 0.00481
# NLP0014I            69         OPT 3.6764039        9 0.004928
# NLP0014I            70         OPT 3.6750228        9 0.004862
# NLP0014I            71         OPT 3.6753679        9 0.004867
# NLP0014I            72         OPT 3.6751217        9 0.004886
# NLP0014I            73         OPT 3.6778451        9 0.004842
# NLP0014I            74         OPT 3.6752016        8 0.004359
# NLP0014I            75         OPT 3.6769173       14 0.007039
# NLP0014I            76         OPT 3.6752016        8 0.004339
# NLP0014I            77         OPT 3.6775157        9 0.002812
# NLP0014I            78         OPT 3.6778266        6 0.003792
# NLP0014I            79         OPT 3.676411        8 0.004265
# NLP0014I            80         OPT 3.6753819       13 0.00689
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            81         OPT 3.6757953       14 0.006136
# NLP0014I            82         OPT 3.6754334       11 0.005826
# NLP0014I            83         OPT 3.6768715       14 0.007065
# NLP0014I            84         OPT 3.6756607        9 0.004791
# NLP0014I            85         OPT 3.6759228       15 0.007355
# NLP0014I            86         OPT 3.6754013       10 0.005205
# NLP0014I            87         OPT 3.6757676        8 0.004294
# NLP0014I            88         OPT 3.6756167       10 0.005245
# NLP0014I            89         OPT 3.6760538       10 0.005211
# NLP0014I            90         OPT 3.6757764        9 0.004749
# NLP0014I            91         OPT 3.6780196       14 0.006937
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 3.4666855       16 0.008267
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 3.4666858        6 0.004351
# NLP0014I             2         OPT 3.4695314        7 0.003858
# NLP0014I             3         OPT 3.4695678        7 0.003849
# NLP0014I             4         OPT 3.4696087        7 0.003873
# NLP0014I             5         OPT 3.4696894        7 0.003913
# NLP0014I             6         OPT 3.4697325        7 0.003885
# NLP0014I             7         OPT 3.4697799        8 0.00424
# NLP0014I             8         OPT 3.4700276        8 0.004274
# NLP0014I             9         OPT 3.4700435        8 0.004257
# NLP0014I            10         OPT 3.4703711        8 0.004329
# NLP0014I            11         OPT 3.4703711        8 0.004518
# NLP0014I            12         OPT 3.4705431        6 0.003413
# NLP0014I            13         OPT 3.4715258        5 0.002863
# NLP0014I            14         OPT 3.4715258        2 0.00138
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 3.4715258        0 0.000436
# NLP0014I             2         OPT 3.4667762        9 0.005525
# NLP0014I             3         OPT 3.4669144       13 0.006851
# NLP0014I             4         OPT 3.4667611        7 0.003896
# NLP0014I             5         OPT 3.4669612       12 0.006346
# NLP0014I             6         OPT 3.466756        7 0.00398
# NLP0014I             7         OPT 3.4669992       14 0.007218
# NLP0014I             8         OPT 3.4667506        7 0.00394
# NLP0014I             9         OPT 3.4670392       10 0.005338
# NLP0014I            10         OPT 3.4668042        8 0.004439
# NLP0014I            11         OPT 3.4669669       13 0.006784
# NLP0014I            12         OPT 3.4667463        7 0.003995
# NLP0014I            13         OPT 3.4670776       10 0.005483
# NLP0014I            14         OPT 3.4667431        7 0.004131
# NLP0014I            15         OPT 3.4671124        9 0.004947
# NLP0014I            16         OPT 3.466741        6 0.003635
# NLP0014I            17         OPT 3.467142        9 0.004897
# NLP0014I            18         OPT 3.4667399        6 0.003457
# NLP0014I            19         OPT 3.4671678        8 0.004521
# NLP0014I            20         OPT 3.466736        6 0.003475
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            21         OPT 3.4671555        8 0.004423
# NLP0014I            22         OPT 3.4695308       10 0.005251
# NLP0014I            23         OPT 3.4845273       15 0.007482
# NLP0014I            24         OPT 3.4685325        9 0.004885
# NLP0014I            25         OPT 3.4666858        6 0.003508
# NLP0014I            26         OPT 3.4695308       10 0.005231
# NLP0014I            27         OPT 3.4695314        7 0.003843
# NLP0014I            28         OPT 3.471314        9 0.004736
# NLP0014I            29         OPT 3.4695709        7 0.003924
# NLP0014I            30         OPT 3.4701182        9 0.004882
# NLP0014I            31         OPT 3.4696819        7 0.003841
# NLP0014I            32         OPT 3.4700653        8 0.004228
# NLP0014I            33         OPT 3.4697237        7 0.003929
# NLP0014I            34         OPT 3.4701544       11 0.005704
# NLP0014I            35         OPT 3.4703589        8 0.004287
# NLP0014I            36         OPT 3.4700935        9 0.004871
# NLP0014I            37         OPT 3.4701041        7 0.003846
# NLP0014I            38         OPT 3.471705       11 0.00561
# NLP0014I            39         OPT 3.4701973        7 0.003756
# NLP0014I            40         OPT 3.4711481       14 0.007042
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            41         OPT 3.4765847        8 0.004217
# NLP0014I            42         OPT 3.4715008       14 0.006902
# NLP0014I            43         OPT 3.4715008       14 0.007035
# NLP0014I            44         OPT 3.4841787        8 0.004166
# NLP0014I            45         OPT 3.4715008       12 0.00597
# NLP0014I            46         OPT 3.4715008       12 0.005955
# NLP0014I            47         OPT 3.4703426        7 0.00375
# NLP0014I            48         OPT 3.4710286        9 0.00477
# NLP0014I            49         OPT 3.4708135        9 0.004858
# NLP0014I            50         OPT 3.4706187        8 0.004196
# NLP0014I            51         OPT 3.4713165        6 0.003351
# NLP0014I            52         OPT 3.4727708       14 0.007423
# NLP0014I            53         OPT 3.4744742        5 0.002938
# NLP0014I            54         OPT 3.4741553       10 0.005264
# NLP0014I            55         OPT 3.4700814        7 0.003887
# NLP0014I            56         OPT 3.4712966        9 0.005017
# NLP0014I            57         OPT 3.4701406        7 0.003837
# NLP0014I            58         OPT 3.4704333       12 0.006047
# NLP0014I            59         OPT 3.4703773        8 0.004303
# NLP0014I            60         OPT 3.4704417        9 0.00488
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            61         OPT 3.470423        8 0.00425
# NLP0014I            62         OPT 3.4708618        9 0.004814
# NLP0014I            63         OPT 3.472498        9 0.004824
# NLP0014I            64         OPT 3.4711794       10 0.005089
# NLP0014I            65         OPT 3.4715379        8 0.004266
# NLP0014I            66         OPT 3.4793255        9 0.004816
# NLP0014I            67         OPT 3.4701234        9 0.004765
# NLP0014I            68         OPT 3.4717082       12 0.006128
# NLP0014I            69         OPT 3.470183        8 0.004359
# NLP0014I            70         OPT 3.4704753       14 0.006983
# NLP0014I            71         OPT 3.4702662        9 0.00497
# NLP0014I            72         OPT 3.4711608       12 0.006285
# NLP0014I            73         OPT 3.4704761        9 0.00477
# NLP0014I            74         OPT 3.4725923        9 0.004796
# NLP0014I            75         OPT 3.4704761        8 0.004247
# NLP0014I            76         OPT 3.4729878       13 0.00679
# NLP0014I            77         OPT 3.4705314        7 0.00413
# NLP0014I            78         OPT 3.4714477       11 0.005844
# NLP0014I            79         OPT 3.4707952        7 0.003854
# NLP0014I            80         OPT 3.4721298       10 0.005128
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            81         OPT 3.4707952        7 0.003988
# NLP0014I            82         OPT 3.4921823        9 0.00482
# NLP0014I            83         OPT 3.4707952        7 0.003955
# NLP0014I            84         OPT 3.4726481        6 0.003503
# NLP0014I            85         OPT 3.4750281        5 0.00291
# NLP0014I            86         OPT 3.4713744        5 0.002897
# NLP0014I             2         OPT 3.4713744        1 0.001807
# NLP0014I            87         OPT 3.4701544        9 0.004963
# NLP0014I            88         OPT 3.4728713       12 0.006007
# NLP0014I            89         OPT 3.4702134        9 0.004748
# NLP0014I            90         OPT 3.4705055       14 0.006983
# NLP0014I            91         OPT 3.4704502        9 0.004909
# NLP0014I            92         OPT 3.4705211       12 0.006121
# NLP0014I            93         OPT 3.4712134        9 0.004649
# NLP0014I            94         OPT 3.4725605        9 0.004732
# NLP0014I            95         OPT 3.4715995       10 0.005206
# NLP0014I            96         OPT 3.479516        8 0.004293
# NLP0014I            97         OPT 3.4703996        9 0.004797
# NLP0014I            98         OPT 3.47079        9 0.004747
# NLP0014I            99         OPT 3.4704533        9 0.00483
# NLP0014I           100         OPT 3.4707412       14 0.006996
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I           101         OPT 3.4706892       10 0.005293
# NLP0014I           102         OPT 3.4708333       13 0.006562
# NLP0014I           103         OPT 3.4715258        9 0.004739
# NLP0014I           104         OPT 3.4726743       12 0.006069
# NLP0014I           105         OPT 3.4704333        9 0.004704
# NLP0014I           106         OPT 3.4734398       14 0.006889
# NLP0014I           107         OPT 3.470782        8 0.004178
# NLP0014I           108         OPT 3.4729021       14 0.006833
# NLP0014I           109         OPT 3.4708217        7 0.003806
# NLP0014I           110         OPT 3.4713461       12 0.00626
# NLP0014I           111         OPT 3.4708671        7 0.003858
# NLP0014I           112         OPT 3.472749       13 0.006575
# NLP0014I           113         OPT 3.4719333        9 0.00484
# NLP0014I           114         OPT 3.4715835        8 0.004309
# NLP0014I           115         OPT 3.4704891       13 0.006598
# NLP0014I           116         OPT 3.4708942       14 0.006951
# NLP0014I           117         OPT 3.4705096        8 0.004296
# NLP0014I           118         OPT 3.4720533       12 0.006255
# NLP0014I           119         OPT 3.4713027        9 0.00473
# NLP0014I           120         OPT 3.471177       11 0.005601
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I           121         OPT 3.4712406       13 0.006827
# NLP0014I           122         OPT 3.4774526        8 0.004504
# NLP0014I           123         OPT 3.4712407        7 0.003869
# NLP0014I             3         OPT 3.4712407        0 0.000997
# ...
# NLP0014I             1         OPT 0.0029585579        6 0.004116
# NLP0014I             2         OPT 0.002961142        7 0.00419
# NLP0014I             3         OPT 0.0029639068        8 0.004675
# NLP0014I             4         OPT 0.0029639082        7 0.004327
# NLP0014I             5         OPT 0.0029639063        7 0.004301
# NLP0014I             6         OPT 0.0030148423        6 0.003707
# NLP0014I             7         OPT 0.0030148445        2 0.001564
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0030148445        0 0.000514
# NLP0014I             2         OPT 0.0029616071        7 0.004752
# NLP0014I             3         OPT 0.0052249484        8 0.004863
# NLP0014I             4         OPT 0.0029613276        7 0.004449
# NLP0014I             5         OPT 0.0040519952        6 0.003821
# NLP0014I             6         OPT 0.0029608642        7 0.00443
# NLP0014I             7         OPT 0.0065444631        7 0.004376
# NLP0014I             8         OPT 0.0029585579        6 0.003889
# NLP0014I             9         OPT 0.0079613217        7 0.004792
# NLP0014I            10         OPT 0.003005627        7 0.004602
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0029705855       11 0.006955
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0029705852        6 0.004553
# NLP0014I             2         OPT 0.0029708538        6 0.006159
# NLP0014I             3         OPT 0.0029733918        6 0.005789
# NLP0014I             4         OPT 0.0029733869        6 0.00511
# NLP0014I             5         OPT 0.002973384        6 0.007193
# NLP0014I             6         OPT 0.0029820396        8 0.006142
# NLP0014I             7         OPT 0.0030589563        6 0.004232
# NLP0014I             8         OPT 0.0030589584        2 0.00155
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0030589584        0 0.000514
# NLP0014I             2         OPT 0.002973525        8 0.005271
# NLP0014I             3         OPT 0.00636875        6 0.003768
# NLP0014I             4         OPT 0.0029734479        7 0.004366
# NLP0014I             5         OPT 0.0050966696        6 0.003684
# NLP0014I             6         OPT 0.0029731443        7 0.004453
# NLP0014I             7         OPT 0.0040155655        6 0.004084
# NLP0014I             8         OPT 0.0029708618        6 0.005243
# NLP0014I             9         OPT 0.0077750257        9 0.007127
# NLP0014I            10         OPT 0.0029705852        6 0.003885
# NLP0014I            11         OPT 0.0092984922        7 0.00446
# NLP0014I            12         OPT 0.0030478339        6 0.005819
# NLP0014I            13         OPT 0.0030589214        7 0.005934
# NLP0014I            14         OPT 0.010977141        7 0.004261
# NLP0014I            15         OPT 0.0030478249        8 0.00435
# NLP0014I            16         OPT 0.012855446        8 0.00462
# NLP0014I            17         OPT 0.0030478249        8 0.004423
# NLP0014I            18         OPT 0.014977066        9 0.00526
# NLP0014I            19         OPT 0.003058956        6 0.004373
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.002973956       12 0.008058
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0029739614        6 0.004664
# NLP0014I             2         OPT 0.0029739555        6 0.004099
# NLP0014I             3         OPT 0.0029739548        6 0.004143
# NLP0014I             4         OPT 0.0029776153        7 0.004652
# NLP0014I             5         OPT 0.0029798457        7 0.004473
# NLP0014I             6         OPT 0.0029871087        9 0.005363
# NLP0014I             7         OPT 0.0031040338        7 0.004198
# NLP0014I             8         OPT 0.0031040685        6 0.00378
# NLP0014I             9         OPT 0.0031040703        2 0.001556
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0031040703        0 0.000526
# NLP0014I             2         OPT 0.0029767099        8 0.005591
# NLP0014I             3         OPT 0.0061549472        6 0.003863
# NLP0014I             4         OPT 0.0029765768        7 0.004409
# NLP0014I             5         OPT 0.0049797447        6 0.003918
# NLP0014I             6         OPT 0.0029762952        7 0.004538
# NLP0014I             7         OPT 0.003986563        6 0.003892
# NLP0014I             8         OPT 0.0029765735        7 0.004437
# NLP0014I             9         OPT 0.007522125        7 0.004498
# NLP0014I            10         OPT 0.0029739614        6 0.003867
# NLP0014I            11         OPT 0.0090219246        9 0.005519
# NLP0014I            12         OPT 0.0030619274        9 0.0053
# NLP0014I            13         OPT 0.0030910466        7 0.004354
# NLP0014I            14         OPT 0.01066851        6 0.004073
# NLP0014I            15         OPT 0.0030619271        9 0.005703
# NLP0014I            16         OPT 0.012507072        7 0.004775
# NLP0014I            17         OPT 0.0031040338        7 0.000521
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0029688605       13 0.007533
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0029688603        7 0.00508
# NLP0014I             2         OPT 0.0029697933        6 0.003898
# NLP0014I             3         OPT 0.0029697871        6 0.003479
# NLP0014I             4         OPT 0.0029697831        6 0.003476
# NLP0014I             5         OPT 0.0029718424        6 0.0035
# NLP0014I             6         OPT 0.0029744057        7 0.004085
# NLP0014I             7         OPT 0.0029744008        7 0.004214
# NLP0014I             8         OPT 0.0029926015        9 0.004983
# NLP0014I             9         OPT 0.0031501429        6 0.003344
# NLP0014I            10         OPT 0.0031501444        2 0.001372
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0031501444        0 0.000453
# NLP0014I             2         OPT 0.0029715352        7 0.00454
# NLP0014I             3         OPT 0.0072261153        6 0.003856
# NLP0014I             4         OPT 0.0029713761        7 0.004517
# NLP0014I             5         OPT 0.0059566445        6 0.003561
# NLP0014I             6         OPT 0.0029712263        7 0.003902
# NLP0014I             7         OPT 0.0048767153        6 0.003365
# NLP0014I             8         OPT 0.0029709703        7 0.003945
# NLP0014I             9         OPT 0.0039661037        7 0.003956
# NLP0014I            10         OPT 0.0029697864        7 0.004209
# NLP0014I            11         OPT 0.008685868        6 0.003919
# NLP0014I            12         OPT 0.0029688603        7 0.004772
# NLP0014I            13         OPT 0.010291384        8 0.005449
# NLP0014I            14         OPT 0.0031007331        9 0.00568
# NLP0014I            15         OPT 0.0031352687        6 0.003873
# NLP0014I            16         OPT 0.012079075        7 0.004456
# NLP0014I            17         OPT 0.0031352687        6 0.003925
# NLP0014I            18         OPT 0.0031501113        7 0.004277
# NLP0014I            19         OPT 0.014094993        6 0.003764
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0029546005       14 0.00792
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0029546102        7 0.004841
# NLP0014I             2         OPT 0.0029564675        7 0.004449
# NLP0014I             3         OPT 0.0029564906        6 0.003899
# NLP0014I             4         OPT 0.002956477        6 0.003972
# NLP0014I             5         OPT 0.002956471        6 0.003912
# NLP0014I             6         OPT 0.0029564677        6 0.003844
# NLP0014I             7         OPT 0.0029587356        7 0.004352
# NLP0014I             8         OPT 0.0029644256        9 0.005469
# NLP0014I             9         OPT 0.0029799389        9 0.005356
# NLP0014I            10         OPT 0.0031971275        6 0.003716
# NLP0014I            11         OPT 0.0031971287        2 0.001545
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0031971287        0 0.000527
# NLP0014I             2         OPT 0.0029572        8 0.005327
# NLP0014I             3         OPT 0.0083097353        7 0.004528
# NLP0014I             4         OPT 0.0029570162        8 0.005366
# NLP0014I             5         OPT 0.0069455985        6 0.004037
# NLP0014I             6         OPT 0.0029568214        8 0.005312
# NLP0014I             7         OPT 0.0057788096        6 0.003944
# NLP0014I             8         OPT 0.0029566869        8 0.004961
# NLP0014I             9         OPT 0.0047899625        6 0.003819
# NLP0014I            10         OPT 0.0029564642        7 0.004529
# NLP0014I            11         OPT 0.0039553337        8 0.005027
# NLP0014I            12         OPT 0.0029546102        7 0.004059
# NLP0014I            13         OPT 0.0098636455        6 0.003655
# NLP0014I            14         OPT 0.0030889886       10 0.005548
# NLP0014I            15         OPT 0.003140465        9 0.005221
# NLP0014I            16         OPT 0.011589826        8 0.00464
# NLP0014I            17         OPT 0.0030889849       10 0.005382
# NLP0014I            18         OPT 0.013533915        9 0.004765
# NLP0014I            19         OPT 0.0031804401        7 0.004221
# NLP0014I            20         OPT 0.0031971011        7 0.004171
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            21         OPT 0.015735161        6 0.003491
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0029312303       14 0.006984
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0029312302        7 0.004484
# NLP0014I             2         OPT 0.0029338468        7 0.003914
# NLP0014I             3         OPT 0.0029338456        7 0.004578
# NLP0014I             4         OPT 0.002935413        7 0.004803
# NLP0014I             5         OPT 0.0029373334        8 0.005439
# NLP0014I             6         OPT 0.0029434382       10 0.006299
# NLP0014I             7         OPT 0.0029711901       10 0.005998
# NLP0014I             8         OPT 0.0031810647        9 0.005537
# NLP0014I             9         OPT 0.0032264991        7 0.004324
# NLP0014I            10         OPT 0.0032449404        8 0.004548
# NLP0014I            11         OPT 0.0032449615        6 0.003765
# NLP0014I            12         OPT 0.0032449625        2 0.001506
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0032449625        0 0.000503
# NLP0014I             2         OPT 0.0029335763        8 0.005488
# NLP0014I             3         OPT 0.0079461742        6 0.003809
# NLP0014I             4         OPT 0.0029333622        8 0.004949
# NLP0014I             5         OPT 0.0066921958        6 0.003757
# NLP0014I             6         OPT 0.0029331881        8 0.004978
# NLP0014I             7         OPT 0.0056250332        6 0.003742
# NLP0014I             8         OPT 0.0029330683        8 0.004866
# NLP0014I             9         OPT 0.0047216935        6 0.003803
# NLP0014I            10         OPT 0.0029328773        7 0.004505
# NLP0014I            11         OPT 0.003946989        8 0.005004
# NLP0014I            12         OPT 0.0029333423        7 0.00442
# NLP0014I            13         OPT 0.009405815        8 0.004782
# NLP0014I            14         OPT 0.0029312302        7 0.004454
# NLP0014I            15         OPT 0.011060545        7 0.004749
# NLP0014I            16         OPT 0.0031207686       10 0.007304
# NLP0014I            17         OPT 0.0031810647        9 0.010721
# NLP0014I            18         OPT 0.012921165        6 0.005321
# NLP0014I            19         OPT 0.0031207667       10 0.007926
# NLP0014I            20         OPT 0.015029218        8 0.006717
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            21         OPT 0.0032264991        7 0.004841
# NLP0014I            22         OPT 0.0032449404        8 0.005137
# NLP0014I            23         OPT 0.017409375        8 0.001193
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0028992966       13 0.00722
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0028992942        7 0.004869
# NLP0014I             2         OPT 0.0029001262        7 0.004431
# NLP0014I             3         OPT 0.0029015093        7 0.004503
# NLP0014I             4         OPT 0.0029032031        8 0.00525
# NLP0014I             5         OPT 0.0029052884       10 0.009277
# NLP0014I             6         OPT 0.0029174636       10 0.005523
# NLP0014I             7         OPT 0.00291746       10 0.005467
# NLP0014I             8         OPT 0.0029174612        9 0.005165
# NLP0014I             9         OPT 0.0029174573        9 0.005084
# NLP0014I            10         OPT 0.0029499106       10 0.005218
# NLP0014I            11         OPT 0.0032935689        8 0.004474
# NLP0014I            12         OPT 0.0032935842        6 0.003487
# NLP0014I            13         OPT 0.003293585        2 0.001465
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.003293585        0 0.000462
# NLP0014I             2         OPT 0.0029015869        8 0.005175
# NLP0014I             3         OPT 0.0089583159        6 0.003495
# NLP0014I             4         OPT 0.0029013644        7 0.004021
# NLP0014I             5         OPT 0.0076164329        6 0.003482
# NLP0014I             6         OPT 0.0029011426        8 0.004516
# NLP0014I             7         OPT 0.006470725        6 0.003442
# NLP0014I             8         OPT 0.0029009899        8 0.004925
# NLP0014I             9         OPT 0.0054986247        6 0.003804
# NLP0014I            10         OPT 0.0029008855        8 0.004879
# NLP0014I            11         OPT 0.0046737597        7 0.004118
# NLP0014I            12         OPT 0.0029007185        7 0.004301
# NLP0014I            13         OPT 0.0039307618        9 0.005272
# NLP0014I            14         OPT 0.0029001369        7 0.004011
# NLP0014I            15         OPT 0.010514254        7 0.004156
# NLP0014I            16         OPT 0.0028992942        7 0.004174
# NLP0014I            17         OPT 0.012280713        6 0.003751
# NLP0014I            18         OPT 0.003153267       10 0.005749
# NLP0014I            19         OPT 0.003222458        9 0.00502
# NLP0014I            20         OPT 0.014283598        7 0.004194
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I            21         OPT 0.0031532661       10 0.005469
# NLP0014I            22         OPT 0.016550559        7 0.003952
# NLP0014I            23         OPT 0.003273371        7 0.003699
# NLP0014I            24         OPT 0.0032935689        8 0.004376
# NLP0014I            25         OPT 0.01908475        6 0.003803

# %%
X.pop()
X = np.array(X).reshape(t_eval.size,nx)
U = np.array(U).reshape(t_eval.size,nu)

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
for k in range(nx):
    plt.plot(t_eval,X[:,k],label=f"x_{k}")
plt.legend()
plt.xlabel("Time")
plt.ylabel("State")

plt.subplot(1,2,2)
for k in range(nu):
    plt.step(t_eval,U[:,k],linestyle="--",label=f"u_{k}")
plt.legend()
plt.xlabel("Time")
plt.ylabel("Control")

plt.savefig("images/chapB_minlp.png")
plt.savefig("images/chapB_minlp.pdf")
plt.show()
